# %% [markdown]
# # Scraping with Pandas

# %%
import pandas as pd

# %% [markdown]
# We can use the `read_html` function in Pandas to automatically scrape any tabular data from a page.

# %%
url = 'https://animalcrossing.fandom.com/wiki/Fish_(New_Horizons)'

# %%
tables = pd.read_html(url)
tables[2]
# Out:
#              Name  Image  Price       Location Shadow size         Time Jan  \
# 0      Bitterling    NaN    900          River           1      All day   ✓
# 1       Pale chub    NaN    200          River           1  9 AM - 4 PM   ✓
# 2    Crucian carp    NaN    160          River           2      All day   ✓
# 3            Dace    NaN    240          River           3  4 PM - 9 AM   ✓
# 4            Carp    NaN    300           Pond           4      All day   ✓
# ..            ...    ...    ...            ...         ...          ...  ..
# 75     Suckerfish    NaN   1500            Sea     4 (Fin)      All day   -
# 76  Football fish    NaN   2500            Sea           4  4 PM - 9 AM   ✓
# 77        Oarfish    NaN   9000            Sea           6      All day   ✓
# 78      Barreleye    NaN  15000            Sea           2  9 PM - 4 AM   ✓
# 79     Coelacanth    NaN  15000  Sea (Raining)           6      All day   ✓
#
#    Feb Mar Apr May Jun Jul Aug Sep Oct Nov Dec
# 0    ✓   ✓   -   -   -   -   -   -   -   ✓   ✓
# 1    ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓
# 2    ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓
# 3    ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓
# 4    ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓
# ..  ..  ..  ..  ..  ..  ..  ..  ..  ..  ..  ..
# 75   -   -   -   -   ✓   ✓   ✓   ✓   -   -   -
# 76   ✓   ✓   -   -   -   -   -   -   -   ✓   ✓
# 77   ✓   ✓   ✓   ✓   -   -   -   -   -   -   ✓
# 78   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓
# 79   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓
#
# [80 rows x 18 columns]

# %% [markdown]
# What we get in return is a list of dataframes for any tabular data that Pandas found.

# %%
type(tables)
# Out:
# list

# %% [markdown]
# We can slice off any of those dataframes that we want using normal indexing.

# %%
df = tables[2]
del df["Image"]
df
# Out:
#              Name  Price       Location Shadow size         Time Jan Feb Mar  \
# 0      Bitterling    900          River           1      All day   ✓   ✓   ✓
# 1       Pale chub    200          River           1  9 AM - 4 PM   ✓   ✓   ✓
# 2    Crucian carp    160          River           2      All day   ✓   ✓   ✓
# 3            Dace    240          River           3  4 PM - 9 AM   ✓   ✓   ✓
# 4            Carp    300           Pond           4      All day   ✓   ✓   ✓
# ..            ...    ...            ...         ...          ...  ..  ..  ..
# 75     Suckerfish   1500            Sea     4 (Fin)      All day   -   -   -
# 76  Football fish   2500            Sea           4  4 PM - 9 AM   ✓   ✓   ✓
# 77        Oarfish   9000            Sea           6      All day   ✓   ✓   ✓
# 78      Barreleye  15000            Sea           2  9 PM - 4 AM   ✓   ✓   ✓
# 79     Coelacanth  15000  Sea (Raining)           6      All day   ✓   ✓   ✓
#
#    Apr May Jun Jul Aug Sep Oct Nov Dec
# 0    -   -   -   -   -   -   -   ✓   ✓
# 1    ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓
# 2    ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓
# 3    ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓
# 4    ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓
# ..  ..  ..  ..  ..  ..  ..  ..  ..  ..
# 75   -   -   ✓   ✓   ✓   ✓   -   -   -
# 76   -   -   -   -   -   -   -   ✓   ✓
# 77   ✓   ✓   -   -   -   -   -   -   ✓
# 78   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓
# 79   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓
#
# [80 rows x 17 columns]

# %% [markdown]
# Set the index to the `State` column

# %%
df.set_index('Name', inplace=True)
df.head()
# Out:
#               Price Location Shadow size         Time Jan Feb Mar Apr May Jun  \
# Name
# Bitterling      900    River           1      All day   ✓   ✓   ✓   -   -   -
# Pale chub       200    River           1  9 AM - 4 PM   ✓   ✓   ✓   ✓   ✓   ✓
# Crucian carp    160    River           2      All day   ✓   ✓   ✓   ✓   ✓   ✓
# Dace            240    River           3  4 PM - 9 AM   ✓   ✓   ✓   ✓   ✓   ✓
# Carp            300     Pond           4      All day   ✓   ✓   ✓   ✓   ✓   ✓
#
#              Jul Aug Sep Oct Nov Dec
# Name
# Bitterling     -   -   -   -   ✓   ✓
# Pale chub      ✓   ✓   ✓   ✓   ✓   ✓
# Crucian carp   ✓   ✓   ✓   ✓   ✓   ✓
# Dace           ✓   ✓   ✓   ✓   ✓   ✓
# Carp           ✓   ✓   ✓   ✓   ✓   ✓

# %% [markdown]
# ## Changing plus and minus to bool

# %%
for i in range(len(df)):
    df["Jan"] = df["Jan"].replace("✓", True)
    df["Feb"] = df["Feb"].replace("✓", True)
    df["Mar"] = df["Mar"].replace("✓", True)
    df["Apr"] = df["Apr"].replace("✓", True)
    df["May"] = df["May"].replace("✓", True)
    df["Jun"] = df["Jun"].replace("✓", True)
    df["Jul"] = df["Jul"].replace("✓", True)
    df["Aug"] = df["Aug"].replace("✓", True)
    df["Sep"] = df["Sep"].replace("✓", True)
    df["Oct"] = df["Oct"].replace("✓", True)
    df["Nov"] = df["Nov"].replace("✓", True)
    df["Dec"] = df["Dec"].replace("✓", True)
    
    df["Jan"] = df["Jan"].replace("-", False)
    df["Feb"] = df["Feb"].replace("-", False)
    df["Mar"] = df["Mar"].replace("-", False)
    df["Apr"] = df["Apr"].replace("-", False)
    df["May"] = df["May"].replace("-", False)
    df["Jun"] = df["Jun"].replace("-", False)
    df["Jul"] = df["Jul"].replace("-", False)
    df["Aug"] = df["Aug"].replace("-", False)
    df["Sep"] = df["Sep"].replace("-", False)
    df["Oct"] = df["Oct"].replace("-", False)
    df["Nov"] = df["Nov"].replace("-", False)
    df["Dec"] = df["Dec"].replace("-", False)

df
# Out:
#                Price       Location Shadow size         Time    Jan    Feb  \
# Name
# Bitterling       900          River           1      All day   True   True
# Pale chub        200          River           1  9 AM - 4 PM   True   True
# Crucian carp     160          River           2      All day   True   True
# Dace             240          River           3  4 PM - 9 AM   True   True
# Carp             300           Pond           4      All day   True   True
# ...              ...            ...         ...          ...    ...    ...
# Suckerfish      1500            Sea     4 (Fin)      All day  False  False
# Football fish   2500            Sea           4  4 PM - 9 AM   True   True
# Oarfish         9000            Sea           6      All day   True   True
# Barreleye      15000            Sea           2  9 PM - 4 AM   True   True
# Coelacanth     15000  Sea (Raining)           6      All day   True   True
#
#                  Mar    Apr    May    Jun    Jul    Aug    Sep    Oct    Nov  \
# Name
# Bitterling      True  False  False  False  False  False  False  False   True
# Pale chub       True   True   True   True   True   True   True   True   True
# Crucian carp    True   True   True   True   True   True   True   True   True
# Dace            True   True   True   True   True   True   True   True   True
# Carp            True   True   True   True   True   True   True   True   True
# ...              ...    ...    ...    ...    ...    ...    ...    ...    ...
# Suckerfish     False  False  False   True   True   True   True  False  False
# Football fish   True  False  False  False  False  False  False  False   True
# Oarfish         True   True   True  False  False  False  False  False  False
# Barreleye       True   True   True   True   True   True   True   True   True
# Coelacanth      True   True   True   True   True   True   True   True   True
#
#                  Dec
# Name
# Bitterling      True
# Pale chub       True
# Crucian carp    True
# Dace            True
# Carp            True
# ...              ...
# Suckerfish     False
# Football fish   True
# Oarfish         True
# Barreleye       True
# Coelacanth      True
#
# [80 rows x 16 columns]

# %% [markdown]
# ## DataFrames as HTML

# %% [markdown]
# Pandas also had a `to_html` method that we can use to generate HTML tables from DataFrames.

# %%
html_table = df.to_html()
html_table
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Image</th>\n      <th>Price</th>\n      <th>Location</th>\n      <th>Shadow Size</th>\n      <th>Time</th>\n      <th>Jan</th>\n      <th>Feb</th>\n      <th>Mar</th>\n      <th>Apr</th>\n      <th>May</th>\n      <th>Jun</th>\n      <th>Jul</th>\n      <th>Aug</th>\n      <th>Sep</th>\n      <th>Oct</th>\n      <th>Nov</th>\n      <th>Dec</th>\n    </tr>\n    <tr>\n      <th>Name</th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>Bitterling</th>\n      <td>NaN</td>\n      <td>900</td>\n      <td>River</td>\n      <td>1</td>\n      <td>All day</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>-</td>\n      <td>-</td>\n      <td>-</td>\n      <td>-</td>\n      <td>-</td>\n      <td>-</td>\n      <td>-</td>\n      <td>✓</td>\n      <td>✓</td>\n    </tr>\n    <tr>\n      <th>Pale chub</th>\n      <td>NaN</td>\n      <td>200</td>\n      <td>River</td>\n      <td>1</td>\n      <td>9 AM - 4 PM</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n    </tr>\n    <tr>\n      <th>Crucian carp</th>\n      <td>NaN</td>\n      <td>160</td>\n      <td>River</td>\n      <td>2</td>\n      <td>All day</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n    </tr>\n    <tr>\n      <th>Dace</th>\n      <td>NaN</td>\n      <td>240</td>\n      <td>River</td>\n      <td>3</td>\n      <td>4 PM - 9 AM</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n    </tr>\n    <tr>\n      <th>Carp</th>\n      <td>NaN</td>\n      <td>300</td>\n      <td>Pond</td>\n      <td>4</td>\n      <td>All day</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n    </tr>\n    <tr>\n      <th>Koi</th>\n      <td>NaN</td>\n      <td>4000</td>\n      <td>Pond</td>\n      <td>4</td>\n      <td>4 PM - 9 AM</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n    </tr>\n    <tr>\n      <th>Goldfish</th>\n      <td>NaN</td>\n      <td>1300</td>\n      <td>Pond</td>\n      <td>1</td>\n      <td>All day</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n    </tr>\n    <tr>\n      <th>Pop-eyed goldfish</th>\n      <td>NaN</td>\n      <td>1300</td>\n      <td>Pond</td>\n      <td>1</td>\n      <td>9 AM - 4 PM</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n    </tr>\n    <tr>\n      <th>Ranchu goldfish</th>\n      <td>NaN</td>\n      <td>4500</td>\n      <td>Pond</td>\n      <td>2</td>\n      <td>9 AM - 4 PM</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      <td>✓</td>\n      ...

# %% [markdown]
# You may have to strip unwanted newlines to clean up the table.

# %%
html_table.replace('\n', '')
# Out:
# '<table border="1" class="dataframe">  <thead>    <tr style="text-align: right;">      <th></th>      <th>Image</th>      <th>Price</th>      <th>Location</th>      <th>Shadow Size</th>      <th>Time</th>      <th>Jan</th>      <th>Feb</th>      <th>Mar</th>      <th>Apr</th>      <th>May</th>      <th>Jun</th>      <th>Jul</th>      <th>Aug</th>      <th>Sep</th>      <th>Oct</th>      <th>Nov</th>      <th>Dec</th>    </tr>    <tr>      <th>Name</th>      <th></th>      <th></th>      <th></th>      <th></th>      <th></th>      <th></th>      <th></th>      <th></th>      <th></th>      <th></th>      <th></th>      <th></th>      <th></th>      <th></th>      <th></th>      <th></th>      <th></th>    </tr>  </thead>  <tbody>    <tr>      <th>Bitterling</th>      <td>NaN</td>      <td>900</td>      <td>River</td>      <td>1</td>      <td>All day</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>-</td>      <td>-</td>      <td>-</td>      <td>-</td>      <td>-</td>      <td>-</td>      <td>-</td>      <td>✓</td>      <td>✓</td>    </tr>    <tr>      <th>Pale chub</th>      <td>NaN</td>      <td>200</td>      <td>River</td>      <td>1</td>      <td>9 AM - 4 PM</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>    </tr>    <tr>      <th>Crucian carp</th>      <td>NaN</td>      <td>160</td>      <td>River</td>      <td>2</td>      <td>All day</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>    </tr>    <tr>      <th>Dace</th>      <td>NaN</td>      <td>240</td>      <td>River</td>      <td>3</td>      <td>4 PM - 9 AM</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>    </tr>    <tr>      <th>Carp</th>      <td>NaN</td>      <td>300</td>      <td>Pond</td>      <td>4</td>      <td>All day</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>    </tr>    <tr>      <th>Koi</th>      <td>NaN</td>      <td>4000</td>      <td>Pond</td>      <td>4</td>      <td>4 PM - 9 AM</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>    </tr>    <tr>      <th>Goldfish</th>      <td>NaN</td>      <td>1300</td>      <td>Pond</td>      <td>1</td>      <td>All day</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>    </tr>    <tr>      <th>Pop-eyed goldfish</th>      <td>NaN</td>      <td>1300</td>      <td>Pond</td>      <td>1</td>      <td>9 AM - 4 PM</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>    </tr>    <tr>      <th>Ranchu goldfish</th>      <td>NaN</td>      <td>4500</td>      <td>Pond</td>      <td>2</td>      <td>9 AM - 4 PM</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>    </tr>    <tr>      <th>Killifish</th>      <td>NaN</td>      <td>300</td>      <td>Pond</td>      <td>1</td>      <td>All day</td>      <td>-</td>      <td>-</td>      <td>-</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>✓</td>      <td>-</td>      <td>-</td>      <td>-</ ...

# %% [markdown]
# You can also save the table directly to a file.

# %%
df.to_html('fish_data.html')
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-13-5510a1854991> in <module>
# ----> 1 df.to_html('fish_data.html')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in to_html(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, max_rows, max_cols, show_dimensions, decimal, bold_rows, classes, escape, notebook, border, table_id, render_links)
#    2315         )
#    2316         # TODO: a generic formatter wld b in DataFrameFormatter
# -> 2317         formatter.to_html(classes=classes, notebook=notebook, border=border)
#    2318
#    2319         if buf is None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\format.py in to_html(self, classes, notebook, border)
#     843         elif isinstance(self.buf, str):
#     844             with open(self.buf, "w") as f:
# --> 845                 buffer_put_lines(f, html)
#     846         else:
#     847             raise TypeError("buf is not a file name and it has no write " " method")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\format.py in buffer_put_lines(buf, lines)
#    1808     if any(isinstance(x, str) for x in lines):
#    1809         lines = [str(x) for x in lines]
# -> 1810     buf.write("\n".join(lines))
#
# C:\ProgramData\Anaconda3\lib\encodings\cp1252.py in encode(self, input, final)
#      17 class IncrementalEncoder(codecs.IncrementalEncoder):
#      18     def encode(self, input, final=False):
# ---> 19         return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#      20
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#
# UnicodeEncodeError: 'charmap' codec can't encode character '\u2713' in position 977: character maps to <undefined>

# %%
# OSX Users can run this to open the file in a browser, 
# or you can manually find the file and open it in the browser
# !open table.html
