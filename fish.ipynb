# %%
import pandas as pd

# %% [markdown]
# # Scraping with Pandas

# %% [markdown]
# We can use the `read_html` function in Pandas to automatically scrape any tabular data from a page.

# %%
url = 'https://animalcrossing.fandom.com/wiki/Fish_(New_Horizons)'

# %%
# Reading url table into a df
tables = pd.read_html(url)
tables[2]
# Out:
#              Name  Image  Price       Location Shadow size         Time Jan  \
# 0      Bitterling    NaN    900          River           1      All day   ✓
# 1       Pale chub    NaN    200          River           1  9 AM - 4 PM   ✓
# 2    Crucian carp    NaN    160          River           2      All day   ✓
# 3            Dace    NaN    240          River           3  4 PM - 9 AM   ✓
# 4            Carp    NaN    300           Pond           4      All day   ✓
# ..            ...    ...    ...            ...         ...          ...  ..
# 75     Suckerfish    NaN   1500            Sea     4 (Fin)      All day   -
# 76  Football fish    NaN   2500            Sea           4  4 PM - 9 AM   ✓
# 77        Oarfish    NaN   9000            Sea           6      All day   ✓
# 78      Barreleye    NaN  15000            Sea           2  9 PM - 4 AM   ✓
# 79     Coelacanth    NaN  15000  Sea (Raining)           6      All day   ✓
#
#    Feb Mar Apr May Jun Jul Aug Sep Oct Nov Dec
# 0    ✓   ✓   -   -   -   -   -   -   -   ✓   ✓
# 1    ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓
# 2    ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓
# 3    ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓
# 4    ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓
# ..  ..  ..  ..  ..  ..  ..  ..  ..  ..  ..  ..
# 75   -   -   -   -   ✓   ✓   ✓   ✓   -   -   -
# 76   ✓   ✓   -   -   -   -   -   -   -   ✓   ✓
# 77   ✓   ✓   ✓   ✓   -   -   -   -   -   -   ✓
# 78   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓
# 79   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓
#
# [80 rows x 18 columns]

# %% [markdown]
# # Data Transformation

# %%
# storing the third table from the url in a df
df = tables[2]
# deleting the image column
del df["Image"]
# displaying the df
df
# Out:
#              Name  Price       Location Shadow size         Time Jan Feb Mar  \
# 0      Bitterling    900          River           1      All day   ✓   ✓   ✓
# 1       Pale chub    200          River           1  9 AM - 4 PM   ✓   ✓   ✓
# 2    Crucian carp    160          River           2      All day   ✓   ✓   ✓
# 3            Dace    240          River           3  4 PM - 9 AM   ✓   ✓   ✓
# 4            Carp    300           Pond           4      All day   ✓   ✓   ✓
# ..            ...    ...            ...         ...          ...  ..  ..  ..
# 75     Suckerfish   1500            Sea     4 (Fin)      All day   -   -   -
# 76  Football fish   2500            Sea           4  4 PM - 9 AM   ✓   ✓   ✓
# 77        Oarfish   9000            Sea           6      All day   ✓   ✓   ✓
# 78      Barreleye  15000            Sea           2  9 PM - 4 AM   ✓   ✓   ✓
# 79     Coelacanth  15000  Sea (Raining)           6      All day   ✓   ✓   ✓
#
#    Apr May Jun Jul Aug Sep Oct Nov Dec
# 0    -   -   -   -   -   -   -   ✓   ✓
# 1    ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓
# 2    ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓
# 3    ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓
# 4    ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓
# ..  ..  ..  ..  ..  ..  ..  ..  ..  ..
# 75   -   -   ✓   ✓   ✓   ✓   -   -   -
# 76   -   -   -   -   -   -   -   ✓   ✓
# 77   ✓   ✓   -   -   -   -   -   -   ✓
# 78   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓
# 79   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓
#
# [80 rows x 17 columns]

# %%
# Replacing check marks with True and minus signs with False
df["Jan"] = df["Jan"].replace("✓", True).replace("-", False)
df["Feb"] = df["Feb"].replace("✓", True).replace("-", False)
df["Mar"] = df["Mar"].replace("✓", True).replace("-", False)
df["Apr"] = df["Apr"].replace("✓", True).replace("-", False)
df["May"] = df["May"].replace("✓", True).replace("-", False)
df["Jun"] = df["Jun"].replace("✓", True).replace("-", False)
df["Jul"] = df["Jul"].replace("✓", True).replace("-", False)
df["Aug"] = df["Aug"].replace("✓", True).replace("-", False)
df["Sep"] = df["Sep"].replace("✓", True).replace("-", False)
df["Oct"] = df["Oct"].replace("✓", True).replace("-", False)
df["Nov"] = df["Nov"].replace("✓", True).replace("-", False)
df["Dec"] = df["Dec"].replace("✓", True).replace("-", False)
    
# Capitalizing the name column
df["Name"] = df["Name"].str.title()

# Displaying df
df
# Out:
#              Name  Price       Location Shadow size         Time    Jan  \
# 0      Bitterling    900          River           1      All day   True
# 1       Pale Chub    200          River           1  9 AM - 4 PM   True
# 2    Crucian Carp    160          River           2      All day   True
# 3            Dace    240          River           3  4 PM - 9 AM   True
# 4            Carp    300           Pond           4      All day   True
# ..            ...    ...            ...         ...          ...    ...
# 75     Suckerfish   1500            Sea     4 (Fin)      All day  False
# 76  Football Fish   2500            Sea           4  4 PM - 9 AM   True
# 77        Oarfish   9000            Sea           6      All day   True
# 78      Barreleye  15000            Sea           2  9 PM - 4 AM   True
# 79     Coelacanth  15000  Sea (Raining)           6      All day   True
#
#       Feb    Mar    Apr    May    Jun    Jul    Aug    Sep    Oct    Nov  \
# 0    True   True  False  False  False  False  False  False  False   True
# 1    True   True   True   True   True   True   True   True   True   True
# 2    True   True   True   True   True   True   True   True   True   True
# 3    True   True   True   True   True   True   True   True   True   True
# 4    True   True   True   True   True   True   True   True   True   True
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 75  False  False  False  False   True   True   True   True  False  False
# 76   True   True  False  False  False  False  False  False  False   True
# 77   True   True   True   True  False  False  False  False  False  False
# 78   True   True   True   True   True   True   True   True   True   True
# 79   True   True   True   True   True   True   True   True   True   True
#
#       Dec
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# ..    ...
# 75  False
# 76   True
# 77   True
# 78   True
# 79   True
#
# [80 rows x 17 columns]

# %% [markdown]
# ## Fish ID df

# %%
# Reading id csv 
filepath = "ids.csv"

# Reading csv into a df
id_df = pd.read_csv(filepath)

# Filtering id df to only contain Fish 
fish_id = id_df.loc[id_df['Type']=='Fish']

# %% [markdown]
# ## Merging ID and fish df

# %%
# Merging fish id and fish df
fish_id_merge = df.merge(fish_id[["ID","Name"]],on='Name',how='left')

# Setting the index to ID
fish_id_merge = fish_id_merge.set_index("ID")

# Displaying the df
fish_id_merge
# Out:
#               Name  Price       Location Shadow size         Time    Jan  \
# ID
# F01     Bitterling    900          River           1      All day   True
# F02      Pale Chub    200          River           1  9 AM - 4 PM   True
# F03   Crucian Carp    160          River           2      All day   True
# F04           Dace    240          River           3  4 PM - 9 AM   True
# F05           Carp    300           Pond           4      All day   True
# ..             ...    ...            ...         ...          ...    ...
# F76     Suckerfish   1500            Sea     4 (Fin)      All day  False
# F77  Football Fish   2500            Sea           4  4 PM - 9 AM   True
# F78        Oarfish   9000            Sea           6      All day   True
# F79      Barreleye  15000            Sea           2  9 PM - 4 AM   True
# F80     Coelacanth  15000  Sea (Raining)           6      All day   True
#
#        Feb    Mar    Apr    May    Jun    Jul    Aug    Sep    Oct    Nov  \
# ID
# F01   True   True  False  False  False  False  False  False  False   True
# F02   True   True   True   True   True   True   True   True   True   True
# F03   True   True   True   True   True   True   True   True   True   True
# F04   True   True   True   True   True   True   True   True   True   True
# F05   True   True   True   True   True   True   True   True   True   True
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# F76  False  False  False  False   True   True   True   True  False  False
# F77   True   True  False  False  False  False  False  False  False   True
# F78   True   True   True   True  False  False  False  False  False  False
# F79   True   True   True   True   True   True   True   True   True   True
# F80   True   True   True   True   True   True   True   True   True   True
#
#        Dec
# ID
# F01   True
# F02   True
# F03   True
# F04   True
# F05   True
# ..     ...
# F76  False
# F77   True
# F78   True
# F79   True
# F80   True
#
# [80 rows x 17 columns]

# %% [markdown]
# ## Splitting dataframe

# %%
# Creating a df for the fish 
fish_df = fish_id_merge.iloc[:,:4]

# Displaying the fish df
fish_df
# Out:
#               Name  Price       Location Shadow size
# ID
# F01     Bitterling    900          River           1
# F02      Pale Chub    200          River           1
# F03   Crucian Carp    160          River           2
# F04           Dace    240          River           3
# F05           Carp    300           Pond           4
# ..             ...    ...            ...         ...
# F76     Suckerfish   1500            Sea     4 (Fin)
# F77  Football Fish   2500            Sea           4
# F78        Oarfish   9000            Sea           6
# F79      Barreleye  15000            Sea           2
# F80     Coelacanth  15000  Sea (Raining)           6
#
# [80 rows x 4 columns]

# %%
# Creating a df for the months fish are available
fish_months_df = fish_id_merge.iloc[:,5:]

# Displaying fish months df
fish_months_df
# Out:
#        Jan    Feb    Mar    Apr    May    Jun    Jul    Aug    Sep    Oct  \
# ID
# F01   True   True   True  False  False  False  False  False  False  False
# F02   True   True   True   True   True   True   True   True   True   True
# F03   True   True   True   True   True   True   True   True   True   True
# F04   True   True   True   True   True   True   True   True   True   True
# F05   True   True   True   True   True   True   True   True   True   True
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# F76  False  False  False  False  False   True   True   True   True  False
# F77   True   True   True  False  False  False  False  False  False  False
# F78   True   True   True   True   True  False  False  False  False  False
# F79   True   True   True   True   True   True   True   True   True   True
# F80   True   True   True   True   True   True   True   True   True   True
#
#        Nov    Dec
# ID
# F01   True   True
# F02   True   True
# F03   True   True
# F04   True   True
# F05   True   True
# ..     ...    ...
# F76  False  False
# F77   True   True
# F78  False   True
# F79   True   True
# F80   True   True
#
# [80 rows x 12 columns]

# %%
# Creating a df for the months fish are available
fish_time_df = fish_id_merge.iloc[:,4:5]

# Displaying fish months df
fish_time_df
# Out:
#             Time
# ID
# F01      All day
# F02  9 AM - 4 PM
# F03      All day
# F04  4 PM - 9 AM
# F05      All day
# ..           ...
# F76      All day
# F77  4 PM - 9 AM
# F78      All day
# F79  9 PM - 4 AM
# F80      All day
#
# [80 rows x 1 columns]

# %% [markdown]
# ## DataFrames as HTML

# %% [markdown]
# Pandas also had a `to_html` method that we can use to generate HTML tables from DataFrames.

# %%
html_table = df.to_html()
html_table
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Name</th>\n      <th>Price</th>\n      <th>Location</th>\n      <th>Shadow size</th>\n      <th>Time</th>\n      <th>Jan</th>\n      <th>Feb</th>\n      <th>Mar</th>\n      <th>Apr</th>\n      <th>May</th>\n      <th>Jun</th>\n      <th>Jul</th>\n      <th>Aug</th>\n      <th>Sep</th>\n      <th>Oct</th>\n      <th>Nov</th>\n      <th>Dec</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>Bitterling</td>\n      <td>900</td>\n      <td>River</td>\n      <td>1</td>\n      <td>All day</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>False</td>\n      <td>False</td>\n      <td>False</td>\n      <td>False</td>\n      <td>False</td>\n      <td>False</td>\n      <td>False</td>\n      <td>True</td>\n      <td>True</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>Pale Chub</td>\n      <td>200</td>\n      <td>River</td>\n      <td>1</td>\n      <td>9 AM - 4 PM</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>Crucian Carp</td>\n      <td>160</td>\n      <td>River</td>\n      <td>2</td>\n      <td>All day</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>Dace</td>\n      <td>240</td>\n      <td>River</td>\n      <td>3</td>\n      <td>4 PM - 9 AM</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n    </tr>\n    <tr>\n      <th>4</th>\n      <td>Carp</td>\n      <td>300</td>\n      <td>Pond</td>\n      <td>4</td>\n      <td>All day</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n    </tr>\n    <tr>\n      <th>5</th>\n      <td>Koi</td>\n      <td>4000</td>\n      <td>Pond</td>\n      <td>4</td>\n      <td>4 PM - 9 AM</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n    </tr>\n    <tr>\n      <th>6</th>\n      <td>Goldfish</td>\n      <td>1300</td>\n      <td>Pond</td>\n      <td>1</td>\n      <td>All day</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n    </tr>\n    <tr>\n      <th>7</th>\n      <td>Pop-Eyed Goldfish</td>\n      <td>1300</td>\n      <td>Pond</td>\n      <td>1</td>\n      <td>9 AM - 4 PM</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n    </tr>\n    <tr>\n      <th>8</th>\n      <td>Ranchu Goldfish</td>\n      <td>4500</td>\n      <td>Pond</td>\n      <td>2</td>\n      <td>9 AM - 4 PM</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n      <td>True</td>\n       ...

# %% [markdown]
# You may have to strip unwanted newlines to clean up the table.

# %%
html_table.replace('\n', '')
# Out:
# '<table border="1" class="dataframe">  <thead>    <tr style="text-align: right;">      <th></th>      <th>Name</th>      <th>Price</th>      <th>Location</th>      <th>Shadow size</th>      <th>Time</th>      <th>Jan</th>      <th>Feb</th>      <th>Mar</th>      <th>Apr</th>      <th>May</th>      <th>Jun</th>      <th>Jul</th>      <th>Aug</th>      <th>Sep</th>      <th>Oct</th>      <th>Nov</th>      <th>Dec</th>    </tr>  </thead>  <tbody>    <tr>      <th>0</th>      <td>Bitterling</td>      <td>900</td>      <td>River</td>      <td>1</td>      <td>All day</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>False</td>      <td>False</td>      <td>False</td>      <td>False</td>      <td>False</td>      <td>False</td>      <td>False</td>      <td>True</td>      <td>True</td>    </tr>    <tr>      <th>1</th>      <td>Pale Chub</td>      <td>200</td>      <td>River</td>      <td>1</td>      <td>9 AM - 4 PM</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>    </tr>    <tr>      <th>2</th>      <td>Crucian Carp</td>      <td>160</td>      <td>River</td>      <td>2</td>      <td>All day</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>    </tr>    <tr>      <th>3</th>      <td>Dace</td>      <td>240</td>      <td>River</td>      <td>3</td>      <td>4 PM - 9 AM</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>    </tr>    <tr>      <th>4</th>      <td>Carp</td>      <td>300</td>      <td>Pond</td>      <td>4</td>      <td>All day</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>    </tr>    <tr>      <th>5</th>      <td>Koi</td>      <td>4000</td>      <td>Pond</td>      <td>4</td>      <td>4 PM - 9 AM</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>    </tr>    <tr>      <th>6</th>      <td>Goldfish</td>      <td>1300</td>      <td>Pond</td>      <td>1</td>      <td>All day</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>    </tr>    <tr>      <th>7</th>      <td>Pop-Eyed Goldfish</td>      <td>1300</td>      <td>Pond</td>      <td>1</td>      <td>9 AM - 4 PM</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>    </tr>    <tr>      <th>8</th>      <td>Ranchu Goldfish</td>      <td>4500</td>      <td>Pond</td>      <td>2</td>      <td>9 AM - 4 PM</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>    </tr>    <tr>      <th>9</th>      <td>Killifish</td>      <td>300</td>      <td>Pond</td>      <td>1</td>      <td>All day</td>      <td>False</td>      <td>False</td>      <td>False</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td>      <td>True</td ...

# %% [markdown]
# You can also save the table directly to a file.

# %%
df.to_html('fish_data.html')

# %%
# OSX Users can run this to open the file in a browser, 
# or you can manually find the file and open it in the browser
# !open table.html
# Out:
# The file /Users/jeremybrent/Documents/Rutgers/Projects/etl_project/table.html does not exist.
