# %%
import pandas as pd
from config import username
from config import password

# %%
username
# Out:
# 'postgres'

# %% [markdown]
# # Scraping with Pandas

# %% [markdown]
# We can use the `read_html` function in Pandas to automatically scrape any tabular data from a page.

# %%
url = 'https://animalcrossing.fandom.com/wiki/Bugs_(New_Horizons)'

# %%
# Reading url table into a df
tables = pd.read_html(url)
tables[3]
# Out:
#                  Name  Image  Price                  Location          Time  \
# 0    Common butterfly    NaN    160                    Flying   4 AM - 7 PM
# 1    Yellow butterfly    NaN    160                    Flying   4 AM - 7 PM
# 2     Tiger butterfly    NaN    240                    Flying   4 AM - 7 PM
# 3   Peacock butterfly    NaN   2500  Flying by Hybrid Flowers   4 AM - 7 PM
# 4   Common bluebottle    NaN    300                    Flying   4 AM - 7 PM
# ..                ...    ...    ...                       ...           ...
# 75           Pill bug    NaN    250             Hitting Rocks  11 PM - 4 PM
# 76          Centipede    NaN    300             Hitting Rocks  4 PM - 11 PM
# 77             Spider    NaN    600             Shaking Trees   7 PM - 8 AM
# 78          Tarantula    NaN   8000             On the Ground   7 PM - 4 AM
# 79           Scorpion    NaN   8000             On the Ground   7 PM - 4 AM
#
#    Jan Feb Mar Apr May Jun Jul Aug Sep Oct Nov Dec
# 0    ✓   ✓   ✓   ✓   ✓   ✓   -   -   ✓   ✓   ✓   ✓
# 1    -   -   ✓   ✓   ✓   ✓   -   -   ✓   ✓   -   -
# 2    -   -   ✓   ✓   ✓   ✓   ✓   ✓   ✓   -   -   -
# 3    -   -   ✓   ✓   ✓   ✓   -   -   -   -   -   -
# 4    -   -   -   ✓   ✓   ✓   ✓   ✓   -   -   -   -
# ..  ..  ..  ..  ..  ..  ..  ..  ..  ..  ..  ..  ..
# 75   ✓   ✓   ✓   ✓   ✓   ✓   -   -   ✓   ✓   ✓   ✓
# 76   ✓   ✓   ✓   ✓   ✓   ✓   -   -   ✓   ✓   ✓   ✓
# 77   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓
# 78   ✓   ✓   ✓   ✓   -   -   -   -   -   -   ✓   ✓
# 79   -   -   -   -   ✓   ✓   ✓   ✓   ✓   ✓   -   -
#
# [80 rows x 17 columns]

# %% [markdown]
# ## Data Transformation

# %%
# storing the third table from the url in a df
df = tables[3]

# deleting the image column
del df['Image']

# displaying the df
df
# Out:
#                  Name  Price                  Location          Time Jan Feb  \
# 0    Common butterfly    160                    Flying   4 AM - 7 PM   ✓   ✓
# 1    Yellow butterfly    160                    Flying   4 AM - 7 PM   -   -
# 2     Tiger butterfly    240                    Flying   4 AM - 7 PM   -   -
# 3   Peacock butterfly   2500  Flying by Hybrid Flowers   4 AM - 7 PM   -   -
# 4   Common bluebottle    300                    Flying   4 AM - 7 PM   -   -
# ..                ...    ...                       ...           ...  ..  ..
# 75           Pill bug    250             Hitting Rocks  11 PM - 4 PM   ✓   ✓
# 76          Centipede    300             Hitting Rocks  4 PM - 11 PM   ✓   ✓
# 77             Spider    600             Shaking Trees   7 PM - 8 AM   ✓   ✓
# 78          Tarantula   8000             On the Ground   7 PM - 4 AM   ✓   ✓
# 79           Scorpion   8000             On the Ground   7 PM - 4 AM   -   -
#
#    Mar Apr May Jun Jul Aug Sep Oct Nov Dec
# 0    ✓   ✓   ✓   ✓   -   -   ✓   ✓   ✓   ✓
# 1    ✓   ✓   ✓   ✓   -   -   ✓   ✓   -   -
# 2    ✓   ✓   ✓   ✓   ✓   ✓   ✓   -   -   -
# 3    ✓   ✓   ✓   ✓   -   -   -   -   -   -
# 4    -   ✓   ✓   ✓   ✓   ✓   -   -   -   -
# ..  ..  ..  ..  ..  ..  ..  ..  ..  ..  ..
# 75   ✓   ✓   ✓   ✓   -   -   ✓   ✓   ✓   ✓
# 76   ✓   ✓   ✓   ✓   -   -   ✓   ✓   ✓   ✓
# 77   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓   ✓
# 78   ✓   ✓   -   -   -   -   -   -   ✓   ✓
# 79   -   -   ✓   ✓   ✓   ✓   ✓   ✓   -   -
#
# [80 rows x 16 columns]

# %%
# given a string, seperate into two columns (start and end),

# %%
# Replacing check marks with True and minus signs with False
df["Jan"] = df["Jan"].replace("✓", True).replace("-", False)
df["Feb"] = df["Feb"].replace("✓", True).replace("-", False)
df["Mar"] = df["Mar"].replace("✓", True).replace("-", False)
df["Apr"] = df["Apr"].replace("✓", True).replace("-", False)
df["May"] = df["May"].replace("✓", True).replace("-", False)
df["Jun"] = df["Jun"].replace("✓", True).replace("-", False)
df["Jul"] = df["Jul"].replace("✓", True).replace("-", False)
df["Aug"] = df["Aug"].replace("✓", True).replace("-", False)
df["Sep"] = df["Sep"].replace("✓", True).replace("-", False)
df["Oct"] = df["Oct"].replace("✓", True).replace("-", False)
df["Nov"] = df["Nov"].replace("✓", True).replace("-", False)
df["Dec"] = df["Dec"].replace("✓", True).replace("-", False)

# Capitalizing the name column
df["Name"] = df["Name"].str.title()

# Displaying df
df
# Out:
#                  Name  Price                  Location          Time    Jan  \
# 0    Common Butterfly    160                    Flying   4 AM - 7 PM   True
# 1    Yellow Butterfly    160                    Flying   4 AM - 7 PM  False
# 2     Tiger Butterfly    240                    Flying   4 AM - 7 PM  False
# 3   Peacock Butterfly   2500  Flying by Hybrid Flowers   4 AM - 7 PM  False
# 4   Common Bluebottle    300                    Flying   4 AM - 7 PM  False
# ..                ...    ...                       ...           ...    ...
# 75           Pill Bug    250             Hitting Rocks  11 PM - 4 PM   True
# 76          Centipede    300             Hitting Rocks  4 PM - 11 PM   True
# 77             Spider    600             Shaking Trees   7 PM - 8 AM   True
# 78          Tarantula   8000             On the Ground   7 PM - 4 AM   True
# 79           Scorpion   8000             On the Ground   7 PM - 4 AM  False
#
#       Feb    Mar    Apr    May    Jun    Jul    Aug    Sep    Oct    Nov  \
# 0    True   True   True   True   True  False  False   True   True   True
# 1   False   True   True   True   True  False  False   True   True  False
# 2   False   True   True   True   True   True   True   True  False  False
# 3   False   True   True   True   True  False  False  False  False  False
# 4   False  False   True   True   True   True   True  False  False  False
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 75   True   True   True   True   True  False  False   True   True   True
# 76   True   True   True   True   True  False  False   True   True   True
# 77   True   True   True   True   True   True   True   True   True   True
# 78   True   True   True  False  False  False  False  False  False   True
# 79  False  False  False   True   True   True   True   True   True  False
#
#       Dec
# 0    True
# 1   False
# 2   False
# 3   False
# 4   False
# ..    ...
# 75   True
# 76   True
# 77   True
# 78   True
# 79  False
#
# [80 rows x 16 columns]

# %% [markdown]
# ## Bug ID DF

# %%
# Reading id csv 
filepath = "ids.csv"

# Reading csv into a df
id_df = pd.read_csv(filepath)

# Filtering id df to only contain Bugs 
bug_id = id_df.loc[id_df['Type']=='Bug']

# %% [markdown]
# ## Merge ID and Bug DF

# %%
# Merging bug id's and the original df
bug_id_merge = df.merge(bug_id[["ID","Name"]],on='Name',how='left')

# Setting index to the id
bug_id_merge = bug_id_merge.set_index("ID")

# Displaying the df
bug_id_merge
# Out:
#                   Name  Price                  Location          Time    Jan  \
# ID
# B01   Common Butterfly    160                    Flying   4 AM - 7 PM   True
# B02   Yellow Butterfly    160                    Flying   4 AM - 7 PM  False
# B03    Tiger Butterfly    240                    Flying   4 AM - 7 PM  False
# B04  Peacock Butterfly   2500  Flying by Hybrid Flowers   4 AM - 7 PM  False
# B05  Common Bluebottle    300                    Flying   4 AM - 7 PM  False
# ..                 ...    ...                       ...           ...    ...
# B76           Pill Bug    250             Hitting Rocks  11 PM - 4 PM   True
# B77          Centipede    300             Hitting Rocks  4 PM - 11 PM   True
# B78             Spider    600             Shaking Trees   7 PM - 8 AM   True
# B79          Tarantula   8000             On the Ground   7 PM - 4 AM   True
# B80           Scorpion   8000             On the Ground   7 PM - 4 AM  False
#
#        Feb    Mar    Apr    May    Jun    Jul    Aug    Sep    Oct    Nov  \
# ID
# B01   True   True   True   True   True  False  False   True   True   True
# B02  False   True   True   True   True  False  False   True   True  False
# B03  False   True   True   True   True   True   True   True  False  False
# B04  False   True   True   True   True  False  False  False  False  False
# B05  False  False   True   True   True   True   True  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# B76   True   True   True   True   True  False  False   True   True   True
# B77   True   True   True   True   True  False  False   True   True   True
# B78   True   True   True   True   True   True   True   True   True   True
# B79   True   True   True  False  False  False  False  False  False   True
# B80  False  False  False   True   True   True   True   True   True  False
#
#        Dec
# ID
# B01   True
# B02  False
# B03  False
# B04  False
# B05  False
# ..     ...
# B76   True
# B77   True
# B78   True
# B79   True
# B80  False
#
# [80 rows x 16 columns]

# %% [markdown]
# ## Splitting tables

# %%
# Creating a df for the fish 
bug_df = bug_id_merge.iloc[:,:3]

# Displaying the fish df
bug_df
# Out:
#                   Name  Price                  Location
# ID
# B01   Common Butterfly    160                    Flying
# B02   Yellow Butterfly    160                    Flying
# B03    Tiger Butterfly    240                    Flying
# B04  Peacock Butterfly   2500  Flying by Hybrid Flowers
# B05  Common Bluebottle    300                    Flying
# ..                 ...    ...                       ...
# B76           Pill Bug    250             Hitting Rocks
# B77          Centipede    300             Hitting Rocks
# B78             Spider    600             Shaking Trees
# B79          Tarantula   8000             On the Ground
# B80           Scorpion   8000             On the Ground
#
# [80 rows x 3 columns]

# %%
# Creating a df for the months fish are available
bug_months_df = bug_id_merge.iloc[:,4:]

# Displaying fish months df
bug_months_df
# Out:
#        Jan    Feb    Mar    Apr    May    Jun    Jul    Aug    Sep    Oct  \
# ID
# B01   True   True   True   True   True   True  False  False   True   True
# B02  False  False   True   True   True   True  False  False   True   True
# B03  False  False   True   True   True   True   True   True   True  False
# B04  False  False   True   True   True   True  False  False  False  False
# B05  False  False  False   True   True   True   True   True  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# B76   True   True   True   True   True   True  False  False   True   True
# B77   True   True   True   True   True   True  False  False   True   True
# B78   True   True   True   True   True   True   True   True   True   True
# B79   True   True   True   True  False  False  False  False  False  False
# B80  False  False  False  False   True   True   True   True   True   True
#
#        Nov    Dec
# ID
# B01   True   True
# B02  False  False
# B03  False  False
# B04  False  False
# B05  False  False
# ..     ...    ...
# B76   True   True
# B77   True   True
# B78   True   True
# B79   True   True
# B80  False  False
#
# [80 rows x 12 columns]

# %%
# Creating a df for the months fish are available
bug_time_df = bug_id_merge.iloc[:,3:4]

# Displaying fish months df
bug_time_df
# Out:
#              Time
# ID
# B01   4 AM - 7 PM
# B02   4 AM - 7 PM
# B03   4 AM - 7 PM
# B04   4 AM - 7 PM
# B05   4 AM - 7 PM
# ..            ...
# B76  11 PM - 4 PM
# B77  4 PM - 11 PM
# B78   7 PM - 8 AM
# B79   7 PM - 4 AM
# B80   7 PM - 4 AM
#
# [80 rows x 1 columns]

# %% [markdown]
# ## Create database connection

# %%
# Creaate connection
connection_string = f"{username}:{password}@localhost:5432/ACNH_Critterpedia"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Confirm tables
engine.table_names()

# %%
bug_df.to_sql(name='bugs', con=engine, if_exists='append', index=True)
bug_months_df.to_sql(name='bugs_months', con=engine, if_exists='append', index=True)
bug_time_df.to_sql(name='bugs_time', con=engine, if_exists='append', index=True)
