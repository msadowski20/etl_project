# %%
import pandas as pd
import csv
import random
from config import username, password
from sqlalchemy import create_engine

# %%
ids = "Resources/ids.csv"

id_df = pd.read_csv(ids)
id_df.head()
# Out:
#     ID              Name Type
# 0  B10  Agrias Butterfly  Bug
# 1  B69               Ant  Bug
# 2  B14        Atlas Moth  Bug
# 3  B68           Bagworm  Bug
# 4  B34  Banded Dragonfly  Bug

# %%
collection_df = pd.DataFrame(columns=['email_address', 'ID', 'type', 'caught', 'donated', 'resident'])
collection_df
# Out:
# Empty DataFrame
# Columns: [email_address, ID, type, caught, donated, resident]
# Index: []

# %%
id_list = id_df['ID'].tolist()
type_list = id_df['Type'].tolist()

id_dict = dict(zip(id_list, type_list))
id_dict
# Out:
# {'B10': 'Bug',
#  'B69': 'Bug',
#  'B14': 'Bug',
#  'B68': 'Bug',
#  'B34': 'Bug',
#  'B21': 'Bug',
#  'B49': 'Bug',
#  'B26': 'Bug',
#  'B77': 'Bug',
#  'B31': 'Bug',
#  'B47': 'Bug',
#  'B05': 'Bug',
#  'B01': 'Bug',
#  'B20': 'Bug',
#  'B59': 'Bug',
#  'B35': 'Bug',
#  'B33': 'Bug',
#  'B39': 'Bug',
#  'B53': 'Bug',
#  'B50': 'Bug',
#  'B51': 'Bug',
#  'B09': 'Bug',
#  'B30': 'Bug',
#  'B36': 'Bug',
#  'B74': 'Bug',
#  'B72': 'Bug',
#  'B28': 'Bug',
#  'B57': 'Bug',
#  'B40': 'Bug',
#  'B61': 'Bug',
#  'B60': 'Bug',
#  'B54': 'Bug',
#  'B19': 'Bug',
#  'B07': 'Bug',
#  'B70': 'Bug',
#  'B24': 'Bug',
#  'B63': 'Bug',
#  'B62': 'Bug',
#  'B64': 'Bug',
#  'B65': 'Bug',
#  'B45': 'Bug',
#  'B43': 'Bug',
#  'B16': 'Bug',
#  'B15': 'Bug',
#  'B42': 'Bug',
#  'B22': 'Bug',
#  'B17': 'Bug',
#  'B56': 'Bug',
#  'B37': 'Bug',
#  'B08': 'Bug',
#  'B73': 'Bug',
#  'B13': 'Bug',
#  'B23': 'Bug',
#  'B06': 'Bug',
#  'B04': 'Bug',
#  'B76': 'Bug',
#  'B38': 'Bug',
#  'B12': 'Bug',
#  'B58': 'Bug',
#  'B11': 'Bug',
#  'B32': 'Bug',
#  'B18': 'Bug',
#  'B27': 'Bug',
#  'B48': 'Bug',
#  'B55': 'Bug',
#  'B52': 'Bug',
#  'B80': 'Bug',
#  'B75': 'Bug',
#  'B78': 'Bug',
#  'B41': 'Bug',
#  'B79': 'Bug',
#  'B44': 'Bug',
#  'B03': 'Bug',
#  'B46': 'Bug',
#  'B29': 'Bug',
#  'B67': 'Bug',
#  'B66': 'Bug',
#  'B25': 'Bug',
#  'B71': 'Bug',
#  'B02': 'Bug',
#  'F56': 'Fish',
#  'F36': 'Fish',
#  'F44': 'Fish',
#  'F41': 'Fish',
#  'F58': 'Fish',
#  'F79': 'Fish',
#  'F37': 'Fish',
#  'F01': 'Fish',
#  'F22': 'Fish',
#  'F54': 'Fish',
#  'F67': 'Fish',
#  'F20': 'Fish',
#  'F51': 'Fish',
#  'F05': 'Fish',
#  'F18': 'Fish',
#  'F28': 'Fish',
#  'F27': 'Fish',
#  'F49': 'Fish',
#  'F80': 'Fish',
#  'F11': 'Fish',
#  'F03': 'Fish',
#  'F61': 'Fish',
#  'F04': 'Fish',
#  'F42': 'Fish',
#  'F77': 'Fish',
#  'F16': 'Fish',
#  'F15': 'Fish',
#  'F43': 'Fish',
#  'F19': 'Fish',
#  'F68': 'Fish',
#  'F29': 'Fish',
#  'F07': 'Fish',
#  'F74': 'Fish',
#  'F34': 'Fish',
#  'F73': 'Fish',
#  'F57': 'Fish',
#  'F10': 'Fish',
#  'F32': 'Fish',
#  'F06': 'Fish',
#  'F17': 'Fish',
#  'F69': 'Fish',
#  'F33': 'Fish',
#  'F64': 'Fish',
#  'F52': 'Fish',
#  'F38': 'Fish',
#  'F35': 'Fish',
#  'F78': 'Fish',
#  'F70': 'Fish',
#  'F62': 'Fish',
#  'F02': 'Fish',
#  'F24': 'Fish',
#  'F40': 'Fish',
#  'F25': 'Fish',
#  'F08': 'Fish',
#  'F55': 'Fish',
#  'F39': 'Fish',
#  'F09': 'Fish',
#  'F71': 'Fish',
#  'F60': 'Fish',
#  'F65': 'Fish',
#  'F45': 'Fish',
#  'F31': 'Fish',
#  'F72': 'Fish',
#  'F59': 'Fish',
#  'F47': 'Fish',
#  'F48': 'Fish',
#  'F13': 'Fish',
#  'F12': 'Fish',
#  'F63': 'Fish',
#  'F30': 'Fish',
#  'F46': 'Fish',
#  'F76': 'Fish',
#  'F50': 'Fish',
#  'F26': 'Fish',
#  'F14': 'Fish',
#  'F23': 'Fish',
#  'F66': 'Fish',
#  'F75': 'Fish',
#  'F21': 'Fish',
#  'F53': 'Fish',
#  'villager-admiral': 'Villager',
#  'villager-agent-s': 'Villager',
#  'villager-agnes': 'Villager',
#  'villager-al': 'Villager',
#  'villager-alfonso': 'Villager',
#  'villager-alice': 'Villager',
#  'villager-alli': 'Villager',
#  'villager-amelia': 'Villager',
#  'villager-anabelle': 'Villager',
#  'villager-anchovy': 'Villager',
#  'villager-angus': 'Villager',
#  'villager-anicotti': 'Villager',
#  'villager-ankha': 'Villager',
#  'villager-annalisa': 'Villager',
#  'villager-annalise': 'Villager',
#  'villager-antonio': 'Villager',
#  'villager-apollo': 'Villager',
#  'villager-apple': 'Villager',
#  'villager-astrid': 'Villager',
#  'villager-audie': 'Villager',
#  'villager-aurora': 'Villager',
#  'villager-ava': 'Villager',
#  'villager-avery': 'Villager',
#  'villager-axel': 'Villager',
#  'villager-baabara': 'Villager',
#  'villager-bam': 'Villager',
#  'villager-bangle': 'Villager',
#  'villager-barold': 'Villager',
#  'villager-bea': 'Villager',
#  'villager-beardo': 'Villager',
#  'villager-beau': 'Villager',
#  'villager-becky': 'Villager',
#  'villager-bella': 'Villager',
#  'villager-benedict': 'Villager',
#  'villager-benjamin': 'Villager',
#  'villager-bertha': 'Villager',
#  'villager-bettina': 'Villager',
#  'villager-bianca': 'Villager',
#  'villager-biff': 'Villager',
#  'villager-big-top': 'Villager',
#  'villager-bill': 'Villager',
#  'villager-billy': 'Villager',
#  'villager-biskit': 'Villager',
#  'villager-bitty': 'Villager',
#  'villager-blaire': 'Villager',
#  'villager-blanche': 'Villager',
#  'villager-bluebear': 'Villager',
#  'villager-bob': 'Villager',
#  'villager-bonbon': 'Villager',
#  'villager-bones': 'Villager',
#  'villager-boomer': 'Villager',
#  'villager-boone': 'Villager',
#  'villager-boots': 'Villager',
#  'villager-boris': 'Villager',
#  'villager-boyd': 'Villager',
#  'villager-bree': 'Villager',
#  'villager-broccolo': 'Villager',
#  'villager-broffina': 'Villager',
#  'villager-bruce': 'Villager',
#  'villager-bubbles': 'Villager',
#  'villager-buck': 'Villager',
#  'villager-bud': 'Villager',
#  'villager-bunnie': 'Villager',
#  'villager-butch': 'Villager',
#  'villager-buzz': 'Villager',
#  'villager-cally': 'Villager',
#  'villager-camofrog': 'Villager',
#  'villager-canberra': 'Villager',
#  'villager-candi': 'Villager',
#  'villager-carmen2': 'Villager',
#  'villager-caroline': 'Villager',
#  'villager-carrie': 'Villager',
#  'villager-cashmere': 'Villager',
#  'villager-celia': 'Villager',
#  'villager-cesar': 'Villager',
#  'villager-chadder': 'Villager',
#  'villager-charlise': 'Villager',
#  'villager-cheri': 'Villager',
#  'villager-cherry': 'Villager',
#  'villager-chester': 'Villager',
#  'villager-chevre': 'Villager',
#  'villager-chief': 'Villager',
#  'villager-chops': 'Villager',
#  'villager-chow': 'Villager',
#  'villager-chrissy': 'Villager',
#  'villager-claude': 'Villager',
#  'villager-claudia': 'Villager',
#  'villager-clay': 'Villager',
#  'villager-cleo': 'Villager',
#  'villager-clyde': 'Villager',
#  'villager-coach': 'Villager',
#  'villager-cobb': 'Villager',
#  'villager-coco': 'Villager',
#  'villager-cole': 'Villager',
#  'villager-colton': 'Villager',
#  'villager-cookie': 'Villager',
#  'villager-cousteau': 'Villager',
#  'villager-cranston': 'Villager',
#  'villager-croque': 'Villager',
#  'villager-cube': 'Villager',
#  'villager-curlos': 'Villager',
#  'villager-curly': 'Villager',
#  'villager-curt': 'Villager',
#  'villager-cyd': 'Villager',
#  'villager-cyrano': 'Villager',
#  'villager-daisy': 'Villager',
#  'villager-deena': 'Villager',
#  'villager-deirdre': 'Villager',
#  'villager-del': 'Villager',
#  'villager-deli': 'Villager',
#  'villager-derwin': 'Villager',
#  'villager-diana': 'Villager',
#  'villager-diva': 'Villager',
#  'villager-dizzy': 'Villager',
#  'villager-dobie': 'Villager',
#  'villager-doc': 'Villager',
#  'villager-dom': 'Villager',
#  'villager-dora': 'Villager',
#  'villager-dotty': 'Villager',
#  'villager-drago': 'Villager',
#  'villager-drake': 'Villager',
#  'villager-drift': 'Villager',
#  'villager-ed': 'Villager',
#  'villager-egbert': 'Villager',
#  'villager-elise': 'Villager',
#  'villager-ellie': 'Villager',
#  'villager-elmer': 'Villager',
#  'villager-eloise': 'Villager',
#  'villager-elvis': 'Villager',
#  'villager-erik': 'Villager',
#  'villager-eugene': 'Villager',
#  'villager-eunice': 'Villager',
#  'villager-fang': 'Villager',
#  'villager-fauna': 'Villager',
#  'villager-felicity': 'Villager',
#  'villager-filbert': 'Villager',
#  'villager-flip': 'Villager',
#  'villager-flo': 'Villager',
#  'villager-flora': 'Villager',
#  'villager-flurry': 'Villager',
#  'villager-francine': 'Villager',
#  'villager-frank': 'Villager',
#  'villager-freckles': 'Villager',
#  'villager-freya': 'Villager',
#  'villager-friga': 'Villager',
#  'villager-frita': 'Villager',
#  'villager-frobert': 'Villager',
#  'villager-fuchsia': 'Villager',
#  'villager-gabi': 'Villager',
#  'villager-gala': 'Villager',
#  'villager-gaston': 'Villager',
#  'villager-gayle': 'Villager',
#  'villager-genji': 'Villager',
#  'villager-gigi': 'Villager',
#  'villager-gladys': 'Villager',
#  'villager-gloria': 'Villager',
#  'villager-goldie': 'Villager',
#  'villager-gonzo': 'Villager',
#  'villager-goose': 'Villager',
#  'villager-graham': 'Villager',
#  'villager-greta': 'Villager',
#  'villager-grizzly': 'Villager',
#  'villager-groucho': 'Villager',
#  'villager-gruff': 'Villager',
#  'villager-gwen': 'Villager',
#  'villager-hamlet': 'Villager',
#  'villager-hamphrey': 'Villager',
#  'villager-hans': 'Villager',
#  'villager-harry': 'Villager',
#  'villager-hazel2': 'Villager',
#  'villager-henry': 'Villager',
#  'villager-hippeux': 'Villager',
#  'villager-hopkins': 'Villager',
#  'villager-hopper': 'Villager',
#  'villager-hornsby': 'Villager',
#  'villager-huck': 'Villager',
#  'villager-hugh': 'Villager',
#  'villager-iggly': 'Villager',
#  'villager-ike': 'Villager',
#  'villager-jacob': 'Villager',
#  'villager-jacques': 'Villager',
#  'villager-jambette': 'Villager',
#  'villager-jay': 'Villager',
#  'villager-jeremiah': 'Villager',
#  'villager-jitters': 'Villager',
#  'villager-joey': 'Villager',
#  'villager-judy': 'Villager',
#  'villager-julia': 'Villager',
#  'villager-julian': 'Villager',
#  'villager-june': 'Villager',
#  'villager-kabuki': 'Villager',
#  'villager-katt': 'Villager',
#  'villager-keaton': 'Villager',
#  'villager-ken': 'Villager',
#  'villager-ketchup': 'Villager',
#  'villager-kevin': 'Villager',
#  'villager-kid-cat': 'Villager',
#  'villager-kidd': 'Villager',
#  'villager-kiki': 'Villager',
#  'villager-kitt': 'Villager',
#  'villager-kitty': 'Villager',
#  'villager-klaus': 'Villager',
#  'villager-knox': 'Villager',
#  'villager-kody': 'Villager',
#  'villager-kyle': 'Villager',
#  'villager-leonardo': 'Villager',
#  'villager-leopold': 'Villager',
#  'villager-lily': 'Villager',
#  'villager-limberg': 'Villager',
#  'villager-lionel': 'Villager',
#  'villager-lobo': 'Villager',
#  'villager-lolly': 'Villager',
#  'villager-lopez': 'Villager',
#  'villager-louie': 'Villager',
#  'villager-lucha': 'Villager',
#  'villager-lucky': 'Villager',
#  'villager-lucy': 'Villager',
#  'villager-lyman': 'Villager',
#  'villager-mac': 'Villager',
#  'villager-maddie': 'Villager',
#  'villager-maelle': 'Villager',
#  'villager-maggie': 'Villager',
#  'villager-mallary': 'Villager',
#  'villager-maple': 'Villager',
#  'villager-marcel': 'Villager',
#  'villager-marcie': 'Villager',
#  'villager-margie': 'Villager',
#  'villager-marina': 'Villager',
#  'villager-marshal': 'Villager',
#  'villager-mathilda': 'Villager',
#  'villager-megan': 'Villager',
#  'villager-melba': 'Villager',
#  'villager-merengue': 'Villager',
#  'villager-merry': 'Villager',
#  'villager-midge': 'Villager',
#  'villager-mint': 'Villager',
#  'villager-mira': 'Villager',
#  'villager-miranda': 'Villager',
#  'villager-mitzi': 'Villager',
#  'villager-moe': 'Villager',
#  'villager-molly': 'Villager',
#  'villager-monique': 'Villager',
#  'villager-monty': 'Villager',
#  'villager-moose': 'Villager',
#  'villager-mott': 'Villager',
#  'villager-muffy': 'Villager',
#  'villager-murphy': 'Villager',
#  'villager-nan': 'Villager',
#  'villager-nana': 'Villager',
#  'villager-naomi': 'Villager',
#  'villager-nate': 'Villager',
#  'villager-nibbles': 'Villager',
#  'villager-norma': 'Villager',
#  'villager-octavian': 'Villager',
#  'villager-ohare': 'Villager',
#  'villager-olaf': 'Villager',
#  'villager-olive': 'Villager',
#  'villager-olivia': 'Villager',
#  'villager-opal': 'Villager',
#  'villager-ozzie': 'Villager',
#  'villager-pancetti': 'Villager',
#  'villager-pango': 'Villager',
#  'villager-paolo': 'Villager',
#  'villager-papi': 'Villager',
#  'villager-pashmina': 'Villager',
#  'villager-pate': 'Villager',
#  'villager-patty': 'Villager',
#  'villager-paula': 'Villager',
#  'villager-peaches': 'Villager',
#  'villager-peanut': 'Villager',
#  'villager-pecan': 'Villager',
#  'villager-peck': 'Villager',
#  'villager-peewee': 'Villager',
#  'villager-peggy': 'Villager',
#  'villager-pekoe': 'Villager',
#  'villager-penelope': 'Villager',
#  'villager-phil': 'Villager',
#  'villager-phoebe': 'Villager',
#  'villager-pierce': 'Villager',
#  'villager-pietro': 'Villager',
#  'villager-pinky': 'Villager',
#  'villager-piper': 'Villager',
#  'villager-pippy': 'Villager',
#  'villager-plucky': 'Villager',
#  'villager-pompom': 'Villager',
#  'villager-poncho': 'Villager',
#  'villager-poppy': 'Villager',
#  'villager-portia': 'Villager',
#  'villager-prince': 'Villager',
#  'villager-puck': 'Villager',
#  'villager-puddles': 'Villager',
#  'villager-pudge': 'Villager',
#  'villager-punchy': 'Villager',
#  'villager-purrl': 'Villager',
#  'villager-queenie': 'Villager',
#  'villager-quillson': 'Villager',
#  'villager-raddle': 'Villager',
#  'villager-rasher': 'Villager',
#  'villager-raymond': 'Villager',
#  'villager-renee': 'Villager',
#  'villager-reneigh': 'Villager',
#  'villager-rex': 'Villager',
#  'villager-rhonda': 'Villager',
#  'villager-ribbot': 'Villager',
#  'villager-ricky': 'Villager',
#  'villager-rizzo': 'Villager',
#  'villager-roald': 'Villager',
#  'villager-robin': 'Villager',
#  'villager-rocco': 'Villager',
#  'villager-rocket': 'Villager',
#  'villager-rod': 'Villager',
#  'villager-rodeo': 'Villager',
#  'villager-rodney': 'Villager',
#  'villager-rolf': 'Villager',
#  'villager-rooney': 'Villager',
#  'villager-rory': 'Villager',
#  'villager-roscoe': 'Villager',
#  'villager-rosie': 'Villager',
#  'villager-rowan': 'Villager',
#  'villager-ruby': 'Villager',
#  'villager-rudy': 'Villager',
#  'villager-sally2': 'Villager',
#  'villager-samson': 'Villager',
#  'villager-sandy': 'Villager',
#  'villager-savannah': 'Villager',
#  'villager-scoot': 'Villager',
#  'villager-shari': 'Villager',
#  'villager-sheldon': 'Villager',
#  'villager-shep': 'Villager',
#  'villager-sherb': 'Villager',
#  'villager-simon': 'Villager',
#  'villager-skye': 'Villager',
#  'villager-sly': 'Villager',
#  'villager-snake': 'Villager',
#  'villager-snooty': 'Villager',
#  'villager-soleil': 'Villager',
#  'villager-sparro': 'Villager',
#  'villager-spike': 'Villager',
#  'villager-spork': 'Villager',
#  'villager-sprinkle': 'Villager',
#  'villager-sprocket': 'Villager',
#  'villager-static': 'Villager',
#  'villager-stella': 'Villager',
#  'villager-sterling': 'Villager',
#  'villager-stinky': 'Villager',
#  'villager-stitches': 'Villager',
#  'villager-stu': 'Villager',
#  'villager-sydney': 'Villager',
#  'villager-sylvana': 'Villager',
#  'villager-sylvia': 'Villager',
#  'villager-t-bone': 'Villager',
#  'villager-tabby': 'Villager',
#  'villager-tad': 'Villager',
#  'villager-tammi': 'Villager',
#  'villager-tammy': 'Villager',
#  'villager-tangy': 'Villager',
#  'villager-tank': 'Villager',
#  'villager-tasha': 'Villager',
#  'villager-teddy': 'Villager',
#  'villager-tex': 'Villager',
#  'villager-tia': 'Villager',
#  'villager-tiffany': 'Villager',
#  'villager-timbra': 'Villager',
#  'villager-tipper': 'Villager',
#  'villager-tom': 'Villager',
#  'villager-truffles': 'Villager',
#  'villager-tucker': 'Villager',
#  'villager-tutu': 'Villager',
#  'villager-twiggy': 'Villager',
#  'villager-tybalt': 'Villager',
#  'villager-ursala': 'Villager',
#  'villager-velma': 'Villager',
#  'villager-vesta': 'Villager',
#  'villager-vic': 'Villager',
#  'villager-victoria': 'Villager',
#  'villager-violet': 'Villager',
#  'villager-vivian': 'Villager',
#  'villager-vladimir': 'Villager',
#  'villager-wade': 'Villager',
#  'villager-walker': 'Villager',
#  'villager-walt': 'Villager',
#  'villager-wart-jr': 'Villager',
#  'villager-weber': 'Villager',
#  'villager-wendy': 'Villager',
#  'villager-whitney': 'Villager',
#  'villager-willow': 'Villager',
#  'villager-winnie': 'Villager',
#  'villager-wolfgang': 'Villager',
#  'villager-yuka': 'Villager',
#  'villager-zell': 'Villager',
#  'villager-zucker': 'Villager'}

# %%
with open('Resources/random_emails.csv') as file:
    reader = csv.reader(file, delimiter=',')
    csv_header = next(reader)
    email_list = list(reader)

email_list
# Out:
# [['animats@mac.com'],
#  ['notaprguy@gmail.com'],
#  ['panolex@sbcglobal.net'],
#  ['amaranth@att.net'],
#  ['paulv@live.com'],
#  ['rddesign@mac.com'],
#  ['jrkorson@mac.com'],
#  ['snunez@gmail.com'],
#  ['shazow@icloud.com'],
#  ['gemmell@optonline.net'],
#  ['jaarnial@optonline.net'],
#  ['linuxhack@yahoo.com'],
#  ['scottlee@comcast.net'],
#  ['mddallara@live.com'],
#  ['jrifkin@me.com'],
#  ['fhirsch@outlook.com'],
#  ['rwelty@live.com'],
#  ['heidrich@gmail.com'],
#  ['chrwin@yahoo.ca'],
#  ['jkegl@verizon.net'],
#  ['reziac@yahoo.com'],
#  ['hedwig@mac.com'],
#  ['amaranth@live.com'],
#  ['stakasa@comcast.net'],
#  ['rhialto@yahoo.ca'],
#  ['barjam@comcast.net'],
#  ['phizntrg@hotmail.com'],
#  ['hmbrand@att.net'],
#  ['rsteiner@mac.com'],
#  ['cfhsoft@gmail.com'],
#  ['gospodin@sbcglobal.net'],
#  ['william@msn.com'],
#  ['jramio@verizon.net'],
#  ['sisyphus@comcast.net'],
#  ['staikos@live.com'],
#  ['mcsporran@comcast.net'],
#  ['policies@aol.com'],
#  ['jlbaumga@outlook.com'],
#  ['mhassel@outlook.com'],
#  ['blixem@yahoo.ca'],
#  ['satch@me.com'],
#  ['inico@att.net'],
#  ['draper@yahoo.com'],
#  ['stefano@live.com'],
#  ['fglock@mac.com'],
#  ['jmgomez@icloud.com'],
#  ['nachbaur@comcast.net'],
#  ['johnh@aol.com'],
#  ['sherzodr@gmail.com'],
#  ['tbusch@mac.com'],
#  ['hahiss@mac.com'],
#  ['offthelip@yahoo.com'],
#  ['mglee@msn.com'],
#  ['gator@verizon.net'],
#  ['unreal@yahoo.com'],
#  ['pakaste@hotmail.com'],
#  ['burniske@aol.com'],
#  ['denton@yahoo.ca'],
#  ['boser@me.com'],
#  ['gamma@outlook.com'],
#  ['sopwith@sbcglobal.net'],
#  ['ovprit@hotmail.com'],
#  ['sagal@yahoo.com'],
#  ['bruck@outlook.com'],
#  ['specprog@msn.com'],
#  ['maneesh@sbcglobal.net'],
#  ['killmenow@optonline.net'],
#  ['fwitness@gmail.com'],
#  ['monkeydo@mac.com'],
#  ['fraser@yahoo.ca'],
#  ['dbrobins@verizon.net'],
#  ['maratb@mac.com'],
#  ['emmanuel@outlook.com'],
#  ['kudra@hotmail.com'],
#  ['bsikdar@msn.com'],
#  ['andale@verizon.net'],
#  ['trygstad@att.net'],
#  ['stakasa@optonline.net'],
#  ['bcevc@verizon.net'],
#  ['evilopie@icloud.com'],
#  ['kmself@att.net'],
#  ['osrin@msn.com'],
#  ['isotopian@mac.com'],
#  ['eidac@msn.com'],
#  ['evilopie@yahoo.ca'],
#  ['harryh@comcast.net'],
#  ['offthelip@mac.com'],
#  ['stevelim@sbcglobal.net'],
#  ['cisugrad@comcast.net'],
#  ['parkes@optonline.net'],
#  ['rbarreira@att.net'],
#  ['sjmuir@sbcglobal.net'],
#  ['eurohack@optonline.net'],
#  ['bader@outlook.com'],
#  ['tjensen@mac.com'],
#  ['smartfart@msn.com'],
#  ['hoangle@live.com'],
#  ['mhouston@msn.com'],
#  ['paulv@verizon.net'],
#  ['adhere@icloud.com']]

# %%
email_list = [item for sublist in email_list for item in sublist]
email_list
# Out:
# ['animats@mac.com',
#  'notaprguy@gmail.com',
#  'panolex@sbcglobal.net',
#  'amaranth@att.net',
#  'paulv@live.com',
#  'rddesign@mac.com',
#  'jrkorson@mac.com',
#  'snunez@gmail.com',
#  'shazow@icloud.com',
#  'gemmell@optonline.net',
#  'jaarnial@optonline.net',
#  'linuxhack@yahoo.com',
#  'scottlee@comcast.net',
#  'mddallara@live.com',
#  'jrifkin@me.com',
#  'fhirsch@outlook.com',
#  'rwelty@live.com',
#  'heidrich@gmail.com',
#  'chrwin@yahoo.ca',
#  'jkegl@verizon.net',
#  'reziac@yahoo.com',
#  'hedwig@mac.com',
#  'amaranth@live.com',
#  'stakasa@comcast.net',
#  'rhialto@yahoo.ca',
#  'barjam@comcast.net',
#  'phizntrg@hotmail.com',
#  'hmbrand@att.net',
#  'rsteiner@mac.com',
#  'cfhsoft@gmail.com',
#  'gospodin@sbcglobal.net',
#  'william@msn.com',
#  'jramio@verizon.net',
#  'sisyphus@comcast.net',
#  'staikos@live.com',
#  'mcsporran@comcast.net',
#  'policies@aol.com',
#  'jlbaumga@outlook.com',
#  'mhassel@outlook.com',
#  'blixem@yahoo.ca',
#  'satch@me.com',
#  'inico@att.net',
#  'draper@yahoo.com',
#  'stefano@live.com',
#  'fglock@mac.com',
#  'jmgomez@icloud.com',
#  'nachbaur@comcast.net',
#  'johnh@aol.com',
#  'sherzodr@gmail.com',
#  'tbusch@mac.com',
#  'hahiss@mac.com',
#  'offthelip@yahoo.com',
#  'mglee@msn.com',
#  'gator@verizon.net',
#  'unreal@yahoo.com',
#  'pakaste@hotmail.com',
#  'burniske@aol.com',
#  'denton@yahoo.ca',
#  'boser@me.com',
#  'gamma@outlook.com',
#  'sopwith@sbcglobal.net',
#  'ovprit@hotmail.com',
#  'sagal@yahoo.com',
#  'bruck@outlook.com',
#  'specprog@msn.com',
#  'maneesh@sbcglobal.net',
#  'killmenow@optonline.net',
#  'fwitness@gmail.com',
#  'monkeydo@mac.com',
#  'fraser@yahoo.ca',
#  'dbrobins@verizon.net',
#  'maratb@mac.com',
#  'emmanuel@outlook.com',
#  'kudra@hotmail.com',
#  'bsikdar@msn.com',
#  'andale@verizon.net',
#  'trygstad@att.net',
#  'stakasa@optonline.net',
#  'bcevc@verizon.net',
#  'evilopie@icloud.com',
#  'kmself@att.net',
#  'osrin@msn.com',
#  'isotopian@mac.com',
#  'eidac@msn.com',
#  'evilopie@yahoo.ca',
#  'harryh@comcast.net',
#  'offthelip@mac.com',
#  'stevelim@sbcglobal.net',
#  'cisugrad@comcast.net',
#  'parkes@optonline.net',
#  'rbarreira@att.net',
#  'sjmuir@sbcglobal.net',
#  'eurohack@optonline.net',
#  'bader@outlook.com',
#  'tjensen@mac.com',
#  'smartfart@msn.com',
#  'hoangle@live.com',
#  'mhouston@msn.com',
#  'paulv@verizon.net',
#  'adhere@icloud.com']

# %%
collection_df['email_address'] = email_list
collection_df
# Out:
#             email_address   ID type caught donated resident
# 0         animats@mac.com  NaN  NaN    NaN     NaN      NaN
# 1     notaprguy@gmail.com  NaN  NaN    NaN     NaN      NaN
# 2   panolex@sbcglobal.net  NaN  NaN    NaN     NaN      NaN
# 3        amaranth@att.net  NaN  NaN    NaN     NaN      NaN
# 4          paulv@live.com  NaN  NaN    NaN     NaN      NaN
# ..                    ...  ...  ...    ...     ...      ...
# 95      smartfart@msn.com  NaN  NaN    NaN     NaN      NaN
# 96       hoangle@live.com  NaN  NaN    NaN     NaN      NaN
# 97       mhouston@msn.com  NaN  NaN    NaN     NaN      NaN
# 98      paulv@verizon.net  NaN  NaN    NaN     NaN      NaN
# 99      adhere@icloud.com  NaN  NaN    NaN     NaN      NaN
#
# [100 rows x 6 columns]

# %%
for index,row in collection_df.iterrows():
    random_id = random.choice(list(id_dict))
    collection_df.loc[index, 'ID'] = random_id
    collection_df.loc[index, 'type'] = id_dict.get(random_id)
    collection_df.loc[index, 'caught'] = random.choice([True, False])
collection_df
# Out:
#             email_address                 ID      type caught donated resident
# 0         animats@mac.com      villager-papi  Villager   True     NaN      NaN
# 1     notaprguy@gmail.com    villager-astrid  Villager   True     NaN      NaN
# 2   panolex@sbcglobal.net                B29       Bug  False     NaN      NaN
# 3        amaranth@att.net    villager-willow  Villager   True     NaN      NaN
# 4          paulv@live.com    villager-croque  Villager   True     NaN      NaN
# ..                    ...                ...       ...    ...     ...      ...
# 95      smartfart@msn.com      villager-gala  Villager   True     NaN      NaN
# 96       hoangle@live.com     villager-maple  Villager  False     NaN      NaN
# 97       mhouston@msn.com  villager-leonardo  Villager  False     NaN      NaN
# 98      paulv@verizon.net     villager-merry  Villager  False     NaN      NaN
# 99      adhere@icloud.com      villager-mint  Villager  False     NaN      NaN
#
# [100 rows x 6 columns]

# %%
for index,row in collection_df.iterrows():
    if collection_df.loc[index, 'caught'] == 'True':
        collection_df.loc[index, 'donated'] = random.choice([True, False])
    else:
        collection_df.loc[index, 'donated'] = 'False'
    
    if collection_df.loc[index, 'type'] == 'Villager':
        collection_df.loc[index, 'resident'] = 'True'
    else:
        collection_df.loc[index, 'resident'] = 'False'
        
collection_df
# Out:
#             email_address                 ID      type caught donated resident
# 0         animats@mac.com      villager-papi  Villager   True   False     True
# 1     notaprguy@gmail.com    villager-astrid  Villager   True   False     True
# 2   panolex@sbcglobal.net                B29       Bug  False   False    False
# 3        amaranth@att.net    villager-willow  Villager   True   False     True
# 4          paulv@live.com    villager-croque  Villager   True   False     True
# ..                    ...                ...       ...    ...     ...      ...
# 95      smartfart@msn.com      villager-gala  Villager   True   False     True
# 96       hoangle@live.com     villager-maple  Villager  False   False     True
# 97       mhouston@msn.com  villager-leonardo  Villager  False   False     True
# 98      paulv@verizon.net     villager-merry  Villager  False   False     True
# 99      adhere@icloud.com      villager-mint  Villager  False   False     True
#
# [100 rows x 6 columns]

# %%
connection_string = f"{username}:{password}@localhost:5432/ACNH_Critterpedia"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Confirm tables
engine.table_names()

# %%
collections_df.to_sql(name='collection', con=engine, if_exists='append', index=True)
